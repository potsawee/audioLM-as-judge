# %%
import json
import re

# %%
label_mapping = {
    "The first.": "A",
    "The second.": "B",
    "The second is better.": "B",
    "The latter is better.": "B",
    "The latter.": "B",
}

# %%
output
# Out:
# {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/6475_a.wav'],
#  'ground_truth': ['The second.'],
#  'loss': 0.3824641704559326,
#  'acc': 1.0,
#  'total': 4,
#  'text': ['The second.</s>'],
#  'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#  'task': ['mos_ABtest']}

# %%
path = "./eval_test_epoch_best_tmhint.json"
with open(path) as f:
    outputs = json.load(f)

count_all, count_correct, count_incorrect, count_tie, error = 0, 0, 0, 0, 0
predictions = []
error = 0
for i, output in enumerate(outputs):
    verdict_text = label_mapping[output['text'][0].strip("</s>")]
    gt = label_mapping[output['ground_truth'][0]]
    
    assert verdict_text in ['A', 'B', 'C', 'D']
    assert gt in ['A', 'B']
    
        
    if verdict_text == "A":
        if gt == "A":
            count_correct += 1
            evaluation = "correct"
        else:
            count_incorrect += 1
            evaluation = "incorrect"
    elif verdict_text == "B":
        if gt == "B":
            count_correct += 1
            evaluation = "correct"
        else:
            count_incorrect += 1
            evaluation = "incorrect"
    elif verdict_text == "C":
        count_tie += 1
        evaluation = 'tie'
    else:
        error += 1
        evaluation = 'error'
    count_all += 1
    predictions.append([evaluation, verdict_text])
print("total:", count_all)
print("correct:   {:.2f}%".format(count_correct/count_all*100))
print("incorrect: {:.2f}%".format(count_incorrect/count_all*100))
print("tie:       {:.2f}%".format(count_tie/count_all*100))
print("error:     {:.2f}%".format(error/count_all*100))
# Out:
# total: 6475
# correct:   66.25%
# incorrect: 33.75%
# tie:       0.00%
# error:     0.00%

# %%
output
# Out:
# {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/1_a.wav'],
#  'ground_truth': ['The first.'],
#  'loss': 0.2701738476753235,
#  'acc': 1.0,
#  'total': 4,
#  'text': ['The first.</s>'],
#  'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#  'task': ['mos_ABtest']}

# %%
output
# Out:
# [{'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/1_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2701738476753235,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/2_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.21524730324745178,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/3_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5780198574066162,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/4_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.368768572807312,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/5_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.3296416997909546,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/6_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5474876761436462,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/7_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5236191749572754,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/8_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.41409119963645935,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/9_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.26786333322525024,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/10_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.1907554268836975,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/11_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.22458907961845398,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/12_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.3951692283153534,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/13_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.31553441286087036,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/14_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.278448224067688,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/15_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2961966395378113,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/16_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.26131772994995117,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/17_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5832806825637817,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/18_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.21625182032585144,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/19_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2749446630477905,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/20_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5213009119033813,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/21_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.562850832939148,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/22_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5918773412704468,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/23_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.2818037271499634,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/24_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.25113487243652344,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/25_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.4913996458053589,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/26_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5062745809555054,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/27_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2956569194793701,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/28_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.26920485496520996,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/29_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3062804937362671,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/30_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.2929978370666504,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/31_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5345150828361511,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/32_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5472726225852966,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/33_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.21289128065109253,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/34_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0

#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/969_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.4663100242614746,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/970_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.27734804153442383,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/971_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.22907090187072754,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/972_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2296607494354248,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/973_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2890741527080536,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/974_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2950126528739929,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/975_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.23994004726409912,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/976_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.31624069809913635,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/977_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.2986542582511902,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/978_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3053319454193115,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/979_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.5610014200210571,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/980_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.348697304725647,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/981_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2693031430244446,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/982_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3391897976398468,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/983_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3538700342178345,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/984_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.3148372173309326,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/985_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3074827194213867,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/986_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.4893876314163208,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/987_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.30741846561431885,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/988_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.26052480936050415,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/989_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.29396992921829224,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/990_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.31981438398361206,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/991_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.30238842964172363,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/992_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2523519992828369,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/993_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2852703630924225,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/994_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.2590879201889038,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/995_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.3220052719116211,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/996_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.2914164066314697,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/997_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.3745150566101074,
#   'acc': 0.75,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/998_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3998410999774933,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/999_a.wav'],
#   'ground_truth': ['The second.'],
#   'loss': 0.2843148708343506,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The second.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  {'id': ['/mnt/bn/audio-visual-llm-data3/wangsiyin/SALMONN/data/tmhint_zhi/wavs/1000_a.wav'],
#   'ground_truth': ['The first.'],
#   'loss': 0.3013962507247925,
#   'acc': 1.0,
#   'total': 4,
#   'text': ['The first.</s>'],
#   'prompt': ['USER: <Speech><SpeechHere></Speech> Could you please indicate which speech sample has better quality?\nASSISTANT:'],
#   'task': ['mos_ABtest']},
#  ...]

# %%
predictions_ab = read_output_file(f"../experiments/tmhintqi/ab_testing/diffall_typhoon2_prompt2.processed.txt")
# Out:
# total: 6482
# error: 3.27%
# accuracy: 48.15%

# %%
predictions_ba = read_output_file(f"../experiments/tmhintqi/ab_testing/diffall_typhoon2_prompt2_BA.processed.txt", reverse=True)
# Out:
# total: 6475
# error: 3.20%
# accuracy: 47.78%

# %%
abba_correct, abba_incorrect, abba_error = 0, 0, 0
for x in predictions_ab + predictions_ba:
    if x[0] == 'correct':
        abba_correct += 1
    elif x[0] == 'incorrect':
        abba_incorrect += 1
    elif x[0] == 'error':
        abba_error += 1
    else:
        raise Exception()
print("total:", abba_correct+abba_incorrect+abba_error)
print("correct: {:.2f}%".format(abba_correct/(abba_correct+abba_incorrect+abba_error)*100))
print("incorrect: {:.2f}%".format(abba_incorrect/(abba_correct+abba_incorrect+abba_error)*100))
# Out:
# total: 12957
# correct: 47.97%
# incorrect: 48.80%

# %% [markdown]
# # System-level Correlation

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
def analyze_correlation_and_plot(list_a, list_b):
    # 1. Compute Pearson correlation
    pearson_corr, _ = stats.pearsonr(list_a, list_b)

    # 2. Compute Spearman correlation
    spearman_corr, _ = stats.spearmanr(list_a, list_b)

    # Print results
    print(f"Pearson Correlation: {pearson_corr:.3f}")
    print(f"Spearman Correlation: {spearman_corr:.3f}")

    # 4. Scatter plot with best-fit line
    plt.figure(figsize=(5, 4))
    plt.scatter(list_a, list_b, color='blue', label='Data points')

    # Best fit line
    coefficients = np.polyfit(list_a, list_b, 1)  # Linear fit (degree=1)
    poly = np.poly1d(coefficients)
    best_fit_line = poly(list_a)

    plt.plot(list_a, best_fit_line, color='red', label='Best Fit Line')
    plt.xlabel('MOS (GT)')
    plt.ylabel('AudioJudge Prediction (Win Rate)')
    plt.title('Scatter Plot with Best Fit Line')
    plt.legend()
    plt.grid()
    plt.show()

# %%
pred_by_system, gts_by_system = {}, {}

reverse = False
path = f"../experiments/tmhintqi/ab_testing/diffall_typhoon2_prompt2.processed.txt"
outputs = []
with open(path, "r") as f:
    for line in f:
        x = json.loads(line)
        outputs.append(x)
for output in outputs:
    audio_a, audio_b = output['data']
    model_a = audio_a['system']
    model_b = audio_b['system']
    if model_a not in pred_by_system: pred_by_system[model_a] = []
    if model_a not in gts_by_system:  gts_by_system[model_a] = []
    if model_b not in pred_by_system: pred_by_system[model_b] = []
    if model_b not in gts_by_system:  gts_by_system[model_b] = []
        
    verdict_text = output['processed']
    assert verdict_text in ['A', 'B', 'C']
        
    if verdict_text == "A":
        pred_by_system[model_a] += [1]
        pred_by_system[model_b] += [0]
    elif verdict_text == "B":
        pred_by_system[model_a] += [0]
        pred_by_system[model_b] += [1]
    elif verdict_text == "C":
        pred_by_system[model_a] += [0.5]
        pred_by_system[model_b] += [0.5]    
    else:
        raise Exception()
        
    gts_by_system[model_a] += [audio_a['Q']]
    gts_by_system[model_b] += [audio_b['Q']]

reverse = True
path = f"../experiments/tmhintqi/ab_testing/diffall_typhoon2_prompt2_BA.processed.txt"
outputs = []
with open(path, "r") as f:
    for line in f:
        x = json.loads(line)
        outputs.append(x)
for output in outputs:
    audio_b, audio_a = output['data']
    model_a = audio_a['system']
    model_b = audio_b['system']
    
    verdict_text = output['processed']
    assert verdict_text in ['A', 'B', 'C']
        
    if verdict_text == "A":
        pred_by_system[model_a] += [1]
        pred_by_system[model_b] += [0]
    elif verdict_text == "B":
        pred_by_system[model_a] += [0]
        pred_by_system[model_b] += [1]
    elif verdict_text == "C":
        pred_by_system[model_a] += [0.5]
        pred_by_system[model_b] += [0.5]    
    else:
        raise Exception()

    gts_by_system[model_a] += [audio_a['Q']]
    gts_by_system[model_b] += [audio_b['Q']]

system_level_pred, system_level_gts = [], []
systems = []
for system, pred in pred_by_system.items():
    gts = gts_by_system[system]
    assert len(pred) == len(gts)
    system_level_pred.append(np.mean(pred)*100)
    system_level_gts.append(np.mean(gts))
    systems.append(system)
analyze_correlation_and_plot(system_level_gts, system_level_pred)
# Out:
# Pearson Correlation: -0.036
# Spearman Correlation: -0.049
